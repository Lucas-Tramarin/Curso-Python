# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-Tramarin/Curso-Python/blob/main/06_12_25A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota1 = float(input("Digite sua primeira nota: "))
nota2 = float(input("Digite sua segunda nota: "))
media = (nota1 + nota2) / 2

if media >= 6:
  print("Aprovado!")
else:
  print("Reprovado")
# Out:
# Digite sua primeira nota: 3
# Digite sua segunda nota: 9
# Aprovado!

# %%
media = float(input("Informe a média: "))

if media > 7:
  print("Aprovado")
elif media < 5:
  print("Reprovado")
else:
  print("Recuperação")
# Out:
# Informe a média: 5
# Recuperação

# %%
num1 = int(input("Digite um número: "))
num2 = int(input("Digite outro número: "))

if num1 > num2:
  print(f"O número {num1} é maior que {num2}")
else:
  print(f"O número {num2} é maior que {num1}")
# Out:
# Digite um número: 6
# Digite outro número: 4
# O número 6 é maior que 4

# %%
numero = int(input("Digite um número inteiro: "))
if numero % 2 == 0:
  print(f"O número {numero} é par")
else:
  print(f"O número {numero} é impar")
# Out:
# Digite um número inteiro: 3425435
# O número 3425435 é impar

# %%
idade = int(input("Digite sua data de nascimento: "))

if idade <= 2007:
  print("Você é maior de idade")
else:
  print("Você é menor de idade")
# Out:
# Digite sua data de nascimento: 2000
# Você é maior de idade

# %%
import datetime

print(datetime.date.today())
# Out:
# 2025-12-06

# %%
# !pip install tzlocal

# %%
import datetime
from tzlocal import get_localzone

local_zone = get_localzone()
hora_local = datetime.datetime.now(local_zone)

print(f"Fuso horário detectado: {local_zone}")
print(f"Hora local: {hora_local}")
# Out:
# Fuso horário detectado: Etc/UTC
# Hora local: 2025-12-06 13:49:53.480980+00:00

# %%
# !pip install pytz

# %%
import pytz
brasilia_timezone = pytz.timezone("America/Sao_Paulo")
hora_brasilia = datetime.datetime.now(brasilia_timezone)
print(f"Hora de Brasília: {hora_brasilia}")
# Out:
# Hora de Brasília: 2025-12-06 10:59:36.082383-03:00

# %%
import datetime

ano_nascimento = int(input("Digite o ano de nascimento: "))
mes_nascimento = int(input("Digite o mês de nascimento: "))
dia_nascimento = int(input("Digite o dia de nascimento: "))

hoje = datetime.date.today()
ano_atual = hoje.year
mes_atual = hoje.month
dia_atual = hoje.day

idade = ano_atual - ano_nascimento
if mes_atual < mes_nascimento:
  idade -= 1
elif mes_atual == mes_nascimento:
  if dia_atual < dia_nascimento:
    idade -= 1
print("A sua idade é: ", idade)
if idade >= 18:
  print("Você é maior de idade.")
else:
  print("Você é menor de idade.")
# Out:
# Digite o ano de nascimento: 2007
# Digite o mês de nascimento: 12
# Digite o dia de nascimento: 6
# A sua idade é:  18
# Você é maior de idade.

# %%
num1 = int(input("Digite um número inteiro: "))
num2 = int(input("Digite outro número inteiro: "))

if num1 == num2:
  print("Os números são iguais")
else:
  print("Os números são diferentes")
# Out:
# Digite um número inteiro: 6
# Digite outro número inteiro: 6
# Os números são iguais

# %%
placarTime1 = int(input("Digite o placar do primeiro time: "))
placarTime2 = int(input("Digite o placar do segundo time: "))

if placarTime1 > placarTime2:
  print(f"O primeiro time venceu com {placarTime1} gols")
elif placarTime2 > placarTime1:
  print(f"O segundo time venceu com {placarTime2} gols")
else:
  print(f"Os times empataram com {placarTime1} gols")
# Out:
# Digite o placar do primeiro time: 5
# Digite o placar do segundo time: 5
# Os times empataram com 5 gols

# %%
idade = int(input("Digite sua idade: "))

if idade >= 5 and idade <= 7:
  print("Você está na categoria Infantil A(entre 5 à 7 anos)")
elif idade >= 8 and idade <= 11:
  print("Você está na categoria Infantil B(entre 8 à 11 anos)")
elif idade == 12 or idade == 13:
  print("Você está na categoria Juvenil A(entre 12 à 13 anos)")
elif idade >= 14 and idade <= 17:
  print("Você está na categoria Juvenil B(entre 14 à 17 anos)")
else:
  print("Você está na categoria Adultos(maiores de 18)")
# Out:
# Digite sua idade: 12
# Você está na categoria Juvenil A(entre 12 à 13 anos)

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

numSoma = num1 + num2
numSub = num1 - num2
numMult = num1 * num2
numDiv = num1 / num2

resSoma = float(input("Informe o resultado da soma dos números: "))
if resSoma == numSoma:
  print("Resultado correto")
else:
  print("Resultado incorreto")

resSub = float(input("Informe o resultado da subtração dos números: "))
if resSub == numSub:
  print("Resultado correto")
else:
  print("Resultado incorreto")

resMult = float(input("Informe o resultado da multiplicação dos números: "))
if resMult == numMult:
  print("Resultado correto")
else:
  print("Resultado incorreto")

resDiv = float(input("Informe o resultado da Divisão dos números: "))
if resDiv == numDiv:
  print("Resultado correto")
else:
  print("Resultado incorreto")
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 2
# Informe o resultado da soma dos números: 4
# Resultado correto
# Informe o resultado da subtração dos números: 0
# Resultado correto
# Informe o resultado da multiplicação dos números: 4
# Resultado correto
# Informe o resultado da Divisão dos números: 1
# Resultado correto
